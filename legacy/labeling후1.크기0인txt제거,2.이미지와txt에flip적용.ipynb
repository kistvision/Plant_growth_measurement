# %% [markdown]
# ### 1. anotation 안된 파일 제거 / 2. flip 적용

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2
import shutil

def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSError:
        print("Error : Creating Directory. " + directory)
        
deleted = './deleted'
createFolder(deleted)
d_cnt = 0

def img(x):
    if 'png' in str(x):
        return x
    else:
        return None

def txt(x):
    if 'txt' in str(x):
        return x
    else:
        return None


home = './'

img_list = list(filter(img, sorted(os.listdir(home))))
txt_list = list(filter(txt, sorted(os.listdir(home))))

n_img = len(img_list)
n_txt = len(txt_list)

while n_img != n_txt:
    if n_img < n_txt:
        for idx,txt in enumerate(txt_list):
            name = txt.split(".")[0] + '.png'
            if name not in img_list:
                txt_dir = os.path.join(home, txt_list[idx])
                shutil.move(txt_dir, deleted)
        n_img = len(img_list)
        n_txt = len(txt_list)

    elif n_img > n_txt:
        for idx,img in enumerate(img_list):
            name = img.split(".")[0] + '.txt'
            if name not in txt_list:
                img_dir = os.path.join(home, img_list[idx])
                shutil.move(img_dir, deleted)
        n_img = len(img_list)
        n_txt = len(txt_list)
            

n = n_img
for idx in range(n):
    img_dir = os.path.join(home, img_list[idx])
    txt_dir = os.path.join(home, txt_list[idx])


    file_size = os.path.getsize(txt_dir)
    if file_size == 0:
        shutil.move(img_dir, deleted)
        shutil.move(txt_dir, deleted)
        print(txt_list[idx],"파일 크기 0이라 제거")
    else:
        # flip txt
        print("{}/{}".format(idx, n))
        lines = []
        f = open(txt_dir, 'r')
        while True:
            line = f.readline()
            if not line:
                break
            lines.append(line.split(" "))

        f.close()

        flipped_txt = 'flipped_' + txt_list[idx]
        flipped_txt_dir = os.path.join(home, flipped_txt)

        f = open(flipped_txt_dir, 'w')
        for line in lines:

            line[1] = str(round(1-float(line[1]),6))
            line[2] = line[2]

            new_line = " ".join(line)
            f.write(new_line)
        f.close()

        #flip img
        flipped_img = cv2.flip(cv2.imread(img_dir),1)

        flipped_img_name = 'flipped_' + img_list[idx]
        flipped_img_dir = os.path.join(home, flipped_img_name)

        cv2.imwrite(flipped_img_dir, flipped_img)
# Out:
# 0/672
# 1/672
# 2/672
# 3/672
# 4/672
# 5/672
# 6/672
# 7/672
# 8/672
# 9/672
# 10/672
# 11/672
# 12/672
# 13/672
# 14/672
# 15/672
# 16/672
# 17/672
# 18/672
# 19/672
# 20/672
# 21/672
# 22/672
# 23/672
# 24/672
# 25/672
# 26/672
# 27/672
# 28/672
# 29/672
# 30/672
# 31/672
# 32/672
# 33/672
# 34/672
# 35/672
# 36/672
# 37/672
# 38/672
# 39/672
# 40/672
# 41/672
# 42/672
# 43/672
# 44/672
# 45/672
# 46/672
# 47/672
# 48/672
# 49/672
# 50/672
# 51/672
# 52/672
# 53/672
# 54/672
# 55/672
# RGB_20220531v1_118.txt 파일 크기 0이라 제거
# RGB_20220531v1_119.txt 파일 크기 0이라 제거
# RGB_20220531v1_120.txt 파일 크기 0이라 제거
# 59/672
# 60/672
# 61/672
# 62/672
# 63/672
# 513/672
# 514/672
# 515/672
# 516/672
# 517/672
# 518/672
# 519/672
# 520/672
# 521/672
# 522/672
# 523/672
# 524/672
# 525/672
# RGB_20220708_182.txt 파일 크기 0이라 제거
# 527/672
# RGB_20220708_185.txt 파일 크기 0이라 제거
# RGB_20220708_186.txt 파일 크기 0이라 제거
# 530/672
# 531/672
# 532/672
# 533/672
# 534/672
# 535/672
# 536/672
# 537/672
# 538/672
# 539/672
# 540/672
# 541/672
# 542/672
# 543/672
# 544/672
# RGB_20220708_202.txt 파일 크기 0이라 제거
# 546/672
# RGB_20220708_204.txt 파일 크기 0이라 제거
# 548/672
# RGB_20220708_206.txt 파일 크기 0이라 제거
# 550/672
# 551/672
# 552/672
# 553/672
# 554/672
# 555/672
# 556/672
# 557/672
# 558/672
# 559/672
# 560/672
# 561/672
# 562/672
# 563/672
# 564/672
# RGB_20220708_222.txt 파일 크기 0이라 제거
# RGB_20220708_224.txt 파일 크기 0이라 제거
# RGB_20220708_225.txt 파일 크기 0이라 제거
# RGB_20220708_227.txt 파일 크기 0이라 제거
# RGB_20220708_228.txt 파일 크기 0이라 제거
# RGB_20220708_229.txt 파일 크기 0이라 제거
# RGB_20220708_23.txt 파일 크기 0이라 제거
# 572/672
# 573/672
# 574/672
# RGB_20220708_233.txt 파일 크기 0이라 제거
# 576/672
# 577/672
# RGB_20220708_236.txt 파일 크기 0이라 제거
# RGB_20220708_237.txt 파일 크기 0이라 제거
# 580/672
# RGB_20220708_239.txt 파일 크기 0이라 제거
# 582/672
# 583/672
# 584/672
# RGB_20220708_243.txt 파일 크기 0이라 제거
# 586/672
# RGB_20220708_246.txt 파일 크기 0이라 제거
# 588/672
# 589/672
# 590/672
# 591/672
# 592/672
# 593/672
# 594/672
# 595/672
# 596/672
# 597/672
# 598/672
# 599/672
# 600/672
# 601/672
# 602/672
# 603/672
# 604/672
# 605/672
# 606/672
# RGB_20220708_32.txt 파일 크기 0이라 제거
# RGB_20220708_33.txt 파일 크기 0이라 제거
# 609/672
# 610/672
# 611/672
# 612/672
# 613/672
# 614/672
# 615/672
# 616/672
# 617/672
# 618/672
# 619/672
# 620/672
# 621/672
# 622/672
# 623/672
# 624/672
# 625/672
# 626/672
# 627/672
# 628/672
# 629/672
# 630/672
# 631/672
# RGB_20220708_6.txt 파일 크기 0이라 제거
# 633/672
# 634/672
# 635/672
# 636/672
# 637/672
# 638/672
# 639/672
# 640/672
# 641/672
# 642/672
# 643/672
# 644/672
# 645/672
# 646/672
# 647/672
# 648/672
# 649/672
# 650/672
# 651/672
# 652/672
# RGB_20220708_8.txt 파일 크기 0이라 제거
# 654/672
# 655/672
# 656/672
# 657/672
# 658/672
# 659/672
# 660/672
# 661/672
# 662/672
# 663/672
# 664/672
# 665/672
# 666/672
# 667/672
# 668/672
# 669/672
# 670/672
# 671/672

# %%
print(n_img, n_txt)
# Out:
# 672 673
